# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiaoliveira-gith/flash-skills-rag/blob/main/aula1-intro-groq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -qU pypdf
# %pip install -U langchain
# %pip install -U langchain-community
# %pip install -U langchain-groq
# %pip install langchain-huggingface
# %pip install langgraph
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.13
#     Uninstalling langchain-1.3.13:
#       Successfully uninstalled langchain-1.3.13
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ...

# %%
from google.colab import userdata
import os
api_key=userdata.get('Groq_API')
os.environ['GROQ_API_KEY'] = api_key

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model='llama-3.3-70b-versatile')

# %%
prompt = '''
messages: Segundo a NASa quais seriam os beneficios de ir para marte
'''

# %%
resposta  = llm.invoke(prompt)

# %%
resposta
# Out:
# AIMessage(content='Olá! Segundo a NASA, há vários benefícios em enviar missões tripuladas para Marte. Aqui estão alguns dos principais:\n\n1. **Expansão da presença humana no espaço**: A exploração de Marte é um passo importante para estabelecer uma presença humana permanente no sistema solar. Isso permitiria que a humanidade se tornasse uma espécie multiplanetária, o que poderia garantir a sobrevivência da humanidade em caso de catástrofes globais.\n\n2. **Avanços científicos**: Uma missão tripulada para Marte proporcionaria oportunidades para realizar experimentos científicos em larga escala, o que poderia levar a descobertas importantes sobre a formação do planeta, sua geologia, atmosfera e potencial para vida.\n\n3. **Desenvolvimento de tecnologias**: O desafio de enviar seres humanos para Marte exigiria o desenvolvimento de tecnologias avançadas, como sistemas de propulsão mais eficientes, habitats espaciais seguros e equipamentos de proteção contra radiação cósmica.\n\n4. **Rec
# ...
